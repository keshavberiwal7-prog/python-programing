# %%
car_dict={"brand":"Ford","model":"Mustang GT","year":1994}
print(car_dict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang GT', 'year': 1994}

# %%
print(car_dict["brand"])
# Out:
# Ford

# %%
print(len(car_dict))
# Out:
# 3

# %%
print(type(car_dict))
# Out:
# <class 'dict'>

# %%
car_dict2={"brand":"Ford","model":"Mustang GT","year":1994,"year":2000}
print(car_dict2)
# Out:
# {'brand': 'Ford', 'model': 'Mustang GT', 'year': 2000}

# %%
x=car_dict.get("model")
x
# Out:
# 'Mustang GT'

# %%
car_dict.keys()
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
car_dict.values()
# Out:
# dict_values(['Ford', 'Mustang GT', 1994])

# %%
car_dict["year"]=1995
print(car_dict)s
# Out:
# {'brand': 'Ford', 'model': 'Mustang GT', 'year': 1995}

# %%
car_dict.update({"year":1996})
car_dict
# Out:
# {'brand': 'Ford', 'model': 'Mustang GT', 'year': 1996}

# %%
d3={"name":"A","year":2024,"Pass":"True","Marks":67}
print(d3)
# Out:
# {'name': 'A', 'year': 2024, 'Pass': 'True', 'Marks': 67}

# %%
del d3["Marks"]
print(d3)
# Out:
# {'name': 'A', 'year': 2024, 'Pass': 'True'}

# %%
d3.clear()
print(d3)
# Out:
# {}

# %%
d3={"name":"A","year":2024,"Pass":"True","Marks":67}
d4=d3.copy()

# %%
print(d4)
# Out:
# {'name': 'A', 'year': 2024, 'Pass': 'True', 'Marks': 67}

# %% [markdown]
# # Nested Dictionarty

# %%
myfamily = {
"chil1" : {
"name" : "Emil",
"year" : 2004
},
"child2" : {
"name" : "Tobias",
"year" : 2007
},
"child3" : {
"name" : "Linus",
"year" : 2011
}
}

# %%
print(myfamily)
# Out:
# {'chil1': {'name': 'Emil', 'year': 2004}, 'child2': {'name': 'Tobias', 'year': 2007}, 'child3': {'name': 'Linus', 'year': 2011}}

# %%
# how to scearch the element
print(myfamily["child2"]["name"])
# Out:
# Tobias

# %%
set1=(1,2,3,4,5,6)
print(set1)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(4 in set1)
# Out:
# True

# %%
set1={1,2,3,4,5,6}
set2={7}
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set1.update(set2)
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
list3=["A","B","C"]
print(list3)
# Out:
# ['A', 'B', 'C']

# %%
set1.update(list3)

# %%
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 'A', 'B', 'C'}
