# %%
age=20
if age>=18:
    print("elegible")
else:
    print("Not elegible")
# Out:
# elegible

# %%
marks=39
if marks>=40:
    print("pass")
else:
    print("fail")
# Out:
# fail

# %%
score=25
if score>=20:
    print("incriment 5%")
else:
    print("incriment 2.5%")
# Out:
# incriment 5%

# %%
salary=10000
if salary>20000:
    print("permoted")
else:
    print("same position")
# Out:
# same position

# %%
num=-5
if num<=0:
    print("positive")
else:    
    print("negative")
# Out:
# positive

# %%
num=18
if num%2==0:
    print("Even")
else:
    print("odd")
# Out:
# Even

# %%
a,b,c=24,45,21
if a>b and a>c:
    print("a is gratest")
elif b>c:
    print("b is greatest")
else:
    print("c is greatest")
# Out:
# b is greatest

# %%
x=int(input("enter a no of choice:"))
if 100>=x>=90:
    print("A grade")
elif 90>x>=80:
    print("B grade")
elif 80>x>=70:
    print("C grade")
elif 70>x>=60:
    print("D grade")
else:
    print("F grade")
# Out:
# enter a no of choice: 99
# A grade

# %% [markdown]
# # Practice que

# %%
x=int(input("a no of your choice"))
if x>0:
    print("no is positive")
elif x==0:
    print("no is nighter positive nor negetive")
else:
    print("no is negetive")
# Out:
# a no of your choice -89
# no is negetive

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Number is even")
else:
    print("Number is odd")
# Out:
# Enter a number:  890987654567
# Number is odd

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Enter your age:  8976565566
# Eligible to vote

# %%
age = int(input("Enter your age: "))
if age > 18:
    print("Adult")
elif age==18:
    print("to be a adult")
else:
    print("Minor")
# Out:
# Enter your age:  17
# Minor
