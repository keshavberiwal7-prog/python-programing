# %%
print("Hello World")
# Out:
# Hello World

# %%
# slicing
a="Hello World"

# %%
print(len(a))
# Out:
# 11

# %%
print(a[2:5])
# Out:
# llo

# %%
print(a[:5])
# Out:
# Hello

# %%
print(a[3:])
# Out:
# lo World

# %%
a="Hello, World"
print(a.upper())
# Out:
# HELLO, WORLD

# %%
a="Hello, World"
print(a.lower())
# Out:
# hello, world

# %%
a=" Hello, World "
print(a.strip())
# Out:
# Hello, World

# %%
a="Hello"
b="World"
c=a+b
print(c)
# Out:
# HelloWorld

# %%
a="Hello"
b="World"
c=a+" "+b
print(c)
# Out:
# Hello World

# %%
age=45
txt="My Name is Keshav, and I am" + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 age=45
# ----> 2 txt="My Name is Keshav, and I am" + age
#       3 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age=45
txt="My Name is Keshav, and I am {}"
print(txt.format(age))
# Out:
# My Name is Keshav, and I am 45

# %%
text="We are the so-called\"Vikings\"from the north."
print(text)
# Out:
# We are the so-called"Vikings"from the north.

# %%
a=24
text="My name is Sanskar,And i am{}"
print(text.format(a))
# Out:
# My name is Sanskar,And i am24

# %%
a="My Name"
b= "Sanskar"
a+" "+b
# Out:
# 'My Name Sanskar'

# %%
print(a.upper())
# Out:
# MY NAME IS SANKSAR

# %%
a="My name is sanskar"
print(a.upper())
# Out:
# MY NAME IS SANSKAR

# %%
a="My name is sanskar"
print(a.lower())
# Out:
# my name is sanskar

# %%
txt="hello, and welcome to my world."
x = txt.capitalize()
print(x)
# Out:
# Hello, and welcome to my world.

# %%
txt="hello, and welcome to my world."
x = txt.title()
print(x)
# Out:
# Hello, And Welcome To My World.

# %%
txt="I Love apples,apple are my fav fruit"
x = txt.count("apple",10,24)
print(x)
# Out:
# 1

# %%
txt="hello, and welcome to my world."
x = txt.find("welcome")
print(x)
# Out:
# 11

# %%
txt="hello, and welcome to my world."
x = txt.find("e")
print(x)
# Out:
# 1

# %%
txt="hello, and welcome to my world."
x = txt.index("welcome")
print(x)
# Out:
# 11

# %%
myTuple= ("John","Peter","Vicky")
x="#".join(myTuple)
print(x)
# Out:
# John#Peter#Vicky

# %%
txt="I like bananas"
x=txt.replace("bananas","apples")
print(x)
# Out:
# I like apples

# %%
txt="I could eat bananas all tha day"
x=txt.partition("apples")
print(x)
# Out:
# ('I could eat bananas all tha day', '', '')

# %%
txt="welcome to the jungle"
x=txt.split()
print(x)
# Out:
# ['welcome', 'to', 'the', 'jungle']

# %%
txt="hello, my name is Peter, I am 26 years old"
x=txt.split(", ")
print(x)
# Out:
# ['hello', 'my name is Peter', 'I am 26 years old']
